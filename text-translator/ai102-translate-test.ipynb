# %% [markdown]
# # Azure Text Translation Service
#
# Python 3.14.3

# %%
pip install azure-ai-translation-text==1.0.1

# %%
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError
from azure.ai.translation.text import TextTranslationClient

apikey = "REPLACE_ME"
region = "REPLACE_ME"

credential = AzureKeyCredential(apikey)
text_translator = TextTranslationClient(credential=credential, region=region)

# %% [markdown]
# ### Running the translation
#
# #### Available Languages:
#
# https://learn.microsoft.com/en-us/azure/ai-services/translator/language-support

# %%
try:
    to_language = ["ja", "ko", "zh-Hans"]
    input_text_elements = ["This is a test"]

    response = text_translator.translate(body=input_text_elements, to_language=to_language)
    translation = response[0] if response else None

    if translation:
        detected_language = translation.detected_language
        if detected_language:
            print(
                f"Detected languages of the input text: {detected_language.language} with score: {detected_language.score}."
            )
        for translated_text in translation.translations:
            print(f"Text was translated to: '{translated_text.to}' and the result is: '{translated_text.text}'.")

except HttpResponseError as exception:
    if exception.error is not None:
        print(f"Error Code: {exception.error.code}")
        print(f"Message: {exception.error.message}")
# Out:
# Detected languages of the input text: en with score: 1.0.
# Text was translated to: 'ja' and the result is: 'これはテストだ'.
# Text was translated to: 'ko' and the result is: '이건 시험이야'.
# Text was translated to: 'zh-Hans' and the result is: '这是个测试'.

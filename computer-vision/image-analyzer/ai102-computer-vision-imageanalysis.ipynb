# %%
pip install azure-ai-vision-imageanalysis==1.0.0
# Out:
# Requirement already satisfied: azure-ai-vision-imageanalysis==1.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: opencv-python==4.13.0.92 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (4.13.0.92)
# Requirement already satisfied: isodate>=0.6.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-vision-imageanalysis==1.0.0) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-vision-imageanalysis==1.0.0) (1.37.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-vision-imageanalysis==1.0.0) (4.15.0)
# Requirement already satisfied: numpy>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from opencv-python==4.13.0.92) (2.2.6)
# Requirement already satisfied: requests>=2.21.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.30.0->azure-ai-vision-imageanalysis==1.0.0) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-vision-imageanalysis==1.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-vision-imageanalysis==1.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-vision-imageanalysis==1.0.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-vision-imageanalysis==1.0.0) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    with open("tiger.jpg", "rb") as image_file:
        binary_data = image_file.read()
except Exception as e:
    raise IOError(f"Error reading file: {e}")

# %%
from azure.ai.vision.imageanalysis import ImageAnalysisClient
from azure.ai.vision.imageanalysis.models import VisualFeatures
from azure.core.credentials import AzureKeyCredential

# %%
endpoint = "REPLACE_ME"
apikey = "REPLACE_ME"

# %%
client = ImageAnalysisClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(apikey)
)

# %%
result = client.analyze(
    image_data=binary_data, # Binary data from your image file
    visual_features=[VisualFeatures.CAPTION, VisualFeatures.TAGS],
    gender_neutral_caption=True,
)

print(result)
# Out:
# {'modelVersion': '2023-10-01', 'captionResult': {'text': 'a tiger with black spots', 'confidence': 0.7038443088531494}, 'metadata': {'width': 3000, 'height': 2000}, 'tagsResult': {'values': [{'name': 'animal', 'confidence': 0.9999706149101257}, {'name': 'mammal', 'confidence': 0.9999344944953918}, {'name': 'tiger', 'confidence': 0.9996744394302368}, {'name': 'big cat', 'confidence': 0.9995312690734863}, {'name': 'bengal tiger', 'confidence': 0.9697718620300293}, {'name': 'big cats', 'confidence': 0.9697220325469971}, {'name': 'siberian tiger', 'confidence': 0.967988908290863}, {'name': 'wildlife', 'confidence': 0.9571473002433777}, {'name': 'terrestrial animal', 'confidence': 0.9501385688781738}, {'name': 'snout', 'confidence': 0.8804364800453186}, {'name': 'zoo', 'confidence': 0.8802259564399719}, {'name': 'fur', 'confidence': 0.8793907761573792}, {'name': 'outdoor', 'confidence': 0.8746220469474792}, {'name': 'whiskers', 'confidence': 0.8699899315834045}, {'name': 'felidae', 'confidence': 0.8555440902709961}, {'name': 'ground', 'confidence': 0.6080660820007324}, {'name': 'cat', 'confidence': 0.5442419052124023}]}}

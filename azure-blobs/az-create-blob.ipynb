# %%
pip install azure-storage-blob[aio]==12.27.1, azure-identity==1.25.2
# Out:
# Collecting azure-storage-blob==12.27.1 (from azure-storage-blob[aio]==12.27.1)
#   Downloading azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-identity==1.25.2
#   Using cached azure_identity-1.25.2-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (1.38.2)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (46.0.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (0.7.2)
# Collecting msal>=1.31.0 (from azure-identity==1.25.2)
#   Downloading msal-1.35.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity==1.25.2)
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (2.32.5)
# Requirement already satisfied: aiohttp>=3.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (1.23.0)
# Requirement already satisfied: idna>=2.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]==12.27.1) (3.11)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (3.0)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity==1.25.2)
#   Using cached pyjwt-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\imaging-pc\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob==12.27.1->azure-storage-blob[aio]==12.27.1) (2026.2.25)
# Downloading azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Downloading azure_identity-1.25.2-py3-none-any.whl (191 kB)
# Downloading msal-1.35.1-py3-none-any.whl (119 kB)
# Using cached pyjwt-2.11.0-py3-none-any.whl (28 kB)
# Using cached msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Installing collected packages: PyJWT, azure-storage-blob, msal, msal-extensions, azure-identity
#
#    ---------------------------------------- 0/5 [PyJWT]
#   Attempting uninstall: azure-storage-blob
#    ---------------------------------------- 0/5 [PyJWT]
#     Found existing installation: azure-storage-blob 12.28.0
#    ---------------------------------------- 0/5 [PyJWT]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#     Uninstalling azure-storage-blob-12.28.0:
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#       Successfully uninstalled azure-storage-blob-12.28.0
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    -------- ------------------------------- 1/5 [azure-storage-blob]
#    ---------------- ----------------------- 2/5 [msal]
#    ---------------- ----------------------- 2/5 [msal]
#    ---------------- ----------------------- 2/5 [msal]
#    ---------------- ----------------------- 2/5 [msal]
#    ------------------------ --------------- 3/5 [msal-extensions]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    -------------------------------- ------- 4/5 [azure-identity]
#    ---------------------------------------- 5/5 [azure-identity]
#
# Successfully installed PyJWT-2.11.0 azure-identity-1.25.2 azure-storage-blob-12.27.1 msal-1.35.1 msal-extensions-1.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from azure.core.exceptions import ResourceExistsError
from azure.storage.blob.aio import BlobServiceClient
from azure.identity.aio import DefaultAzureCredential

# %%
class ContainerSamples(object):

    async def create_blob_container(self, blob_service_client: BlobServiceClient, container_name):
        try:
            await blob_service_client.create_container(name=container_name)
        except ResourceExistsError:
            print(f'A container with the name {container_name} already exists')

    async def create_blob_root_container(self, blob_service_client: BlobServiceClient):
        try:
            await blob_service_client.create_container(name="$root")
        except ResourceExistsError:
            print('A container with the name $root already exists')

# %%
async def main():
    sample = ContainerSamples()
    account_url = "https://ai102workspace8564058839.blob.core.windows.net"

    async with DefaultAzureCredential() as credential:
        async with BlobServiceClient(account_url, credential=credential) as blob_service_client:
            await sample.create_blob_root_container(blob_service_client)    
            await sample.create_blob_container(blob_service_client, "sample-container")
    
await main()
# Out:
# A container with the name $root already exists
# A container with the name sample-container already exists
